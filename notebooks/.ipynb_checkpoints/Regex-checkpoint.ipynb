# %%
import pandas as pd
import re
#USE REGEX101 WEBSITE

# %% [markdown]
# ![Alt text](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwww.git-tower.com%2Flearn%2Fmedia%2Fpages%2Fcheat-sheets%2Fregex%2Fff4d11d2b0-1715177552%2Fregex-cheat-sheet.png&f=1&nofb=1&ipt=b0805fd4d7b8647af34f14c15fc9227100bf111c434b05a081ef1fd257f148d5)

# %% [markdown]
# ## re.search()

# %%
text = """Hello World.
I love Python!!!!!
My first lucky number is 987-654-321
My second lucky number is 876-543-210
My third lucky number is 765-432-100
My fourth lucky number is 123-456-123-123-456
"""

# %%
# return the first match
re.search(\d)
